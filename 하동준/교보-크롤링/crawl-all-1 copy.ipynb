# %%
import pandas as pd
import numpy as np
import os
from tqdm import tqdm

# %%
from selenium import webdriver
from selenium.webdriver.chrome import service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.keys import Keys
from selenium.common.exceptions import WebDriverException as WDE
from selenium.common.exceptions import NoSuchElementException, InvalidSessionIdException


import pandas as pd
import time

# %%
isbns = pd.read_csv('isbns.csv')
isbns
theme = isbns.columns.tolist()
isbns_ll = isbns.values.tolist()
len(isbns_ll[0])
# Out:
# 1404

# %%
# theme

# %%
# parser.py
import requests
from bs4 import BeautifulSoup as bs
# Out:
# /opt/conda/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.9) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
options = Options()
options.add_argument("--no-sandbox") #bypass OS security model
options.add_argument("--headless")
options.add_argument("--disable-dev-shm-usage")

# %%
from selenium.webdriver.common.by import By

# %% [markdown]
# > # 다 파싱

# %%
isbns_ll[1][0]
# Out:
# 9788932909707

# %%
len(isbns_ll)
# Out:
# 6

# %%
samples = isbns_ll[0][:10]
samples
# Out:
# [9788983928061,
#  9788983928030,
#  9788983928054,
#  9791131992272,
#  9788937460258,
#  9788983927705,
#  9791133440054,
#  9788992711937,
#  9788983927682,
#  9791191667103]

# %%
# theme

# %%
new = isbns_ll[2:]

# %%
ttt = pd.read_csv('/opt/ml/finalproject/book-data/영미_kyobo.csv')
len(ttt)
# Out:
# 1404

# %%
theme[40]
# Out:
# '9788983928207.1'

# %%
a = pd.read_csv('isbns.csv')
a
theme = a.columns.tolist()

# %% [markdown]
# > # yes24 장르소설만 isbn 다시 가져오기

# %%
import re
import requests
import pandas as pd
from bs4 import BeautifulSoup
from tqdm import tqdm
import numpy as np

# %%
baseurl = 'http://www.yes24.com/24/Category/Display/001001046' + '011' + '?FetchSize=40&ParamSortTp=01&PageNumber='
links = []
for i in tqdm(range(1,37)):
    url = baseurl + str(2)
    res = requests.get(url)
    soup = BeautifulSoup(res.content, 'html.parser')
    class1 = soup.find('ul',class_='clearfix')
    if res.status_code == 200:
        for li in class1.find_all('li'):
            a = li.find('a')
            if a:
                if a['href'][0] == '/':
                    # print(a['href'])
                    yes24 = 'http://yes24.com'
                    product_link = yes24 + a['href']
                    links.append(product_link)
print(len(links))
# big_links.append(links)
# len(big_links)
# Out:
# 100%|██████████| 36/36 [00:28<00:00,  1.25it/s]
# 1440

# %%
import grequests
# Out:
# /opt/conda/lib/python3.8/site-packages/grequests.py:22: MonkeyPatchWarning: Monkey-patching ssl after ssl has already been imported may lead to errors, including RecursionError on Python 3.6. It may also silently lead to incorrect behaviour on Python 3.7. Please monkey-patch earlier. See https://github.com/gevent/gevent/issues/1016. Modules that had direct imports (NOT patched): ['urllib3.util (/opt/conda/lib/python3.8/site-packages/urllib3/util/__init__.py)', 'urllib3.util.ssl_ (/opt/conda/lib/python3.8/site-packages/urllib3/util/ssl_.py)'].
#   curious_george.patch_all(thread=False, select=False)

# %%
reqs = (grequests.get(link) for link in links)
resp = grequests.imap(reqs,grequests.Pool(10))

theme = []

for r in tqdm(resp):
    soup2 = BeautifulSoup(r.content, 'html.parser')
    tag = '#infoset_specific > div.infoSetCont_wrap > div > table > tbody > tr:nth-child(3) > td'
    isbn = soup2.select(tag)
    if isbn:
        c = isbn[0].text
        # print(c)
        # print(isbn)
        theme.append(c)
print(len(theme))
# Out:
# 1440it [10:01,  2.39it/s]
# 1404

# %%
theme
# Out:
# ['9788998274412',
#  '9791104911521',
#  '9791190157346',
#  '9788983928207',
#  '9788934967576',
#  '9788998274795',
#  '9791127844745',
#  '9791157107223',
#  '9788934967323',
#  '9791158887605',
#  '9788934967316',
#  '9788990982575',
#  '9788983927668',
#  '9788934967330',
#  '9791167900869',
#  '9791197063275',
#  '9791167900821',
#  '9788983927675',
#  '9788934967378',
#  '9788934967385',
#  '9788934967361',
#  '9791158887544',
#  '9788932903194',
#  '9791130681429',
#  '9788934967354',
#  '9791191718034',
#  '9791157403394',
#  '9788934967347',
#  '9788972750031',
#  '9788972757573',
#  '9791189015381',
#  '9791190157513',
#  '9788983927705',
#  '9
#  '9791189015381',
#  '9791190157513',
#  '9788983927705',
#  '9788976041470',
#  '9788983927682',
#  '9788963716442',
#  '9791164050277',
#  '9788983927712',
#  '9791190157278',
#  '9791104911521',
#  '9788998274412',
#  '9791190157346',
#  '9788983928207',
#  '9788934967576',
#  '9788998274795',
#  '9791127844745',
#  '9791157107223',
#  '9788934967323',
#  '9791158887605',
#  '9788934967316',
#  '9788990982575',
#  '9788983927668',
#  '9788934967330',
#  '9791167900869',
#  '9791197063275',
#  '9788983927675',
#  '9791167900821',
#  '9788934967378',
#  '9788934967385',
#  '9788934967361',
#  '9791158887544',
#  '9788932903194',
#  '9791130681429',
#  '9791191718034',
#  ...]

# %%
import re

# breakpoints = None
# nara = ['시_희곡', '비평_창작_이론', '한국','영미']
# # nara = ['테마','고전','시/희곡', '비평/창작/이론', '한국','영미']


# for genreidx,genre in enumerate(new):
#     # ll = []
#     data = pd.DataFrame()
#     s=Service('/opt/ml/chromedriver')
#     driver = webdriver.Chrome(options=options, service=s)
#     driver.implicitly_wait(5)
#     keywordpick = []
#     keywords = []
#     isbn_t = []
#     description = []
#     mokcha = []
#     catchphrase = []
#     title = []
#     author = []
#     image = []
#     for idx,isbn in enumerate(tqdm(genre)):
#         genre_info = nara[genreidx]
#         isbn_t.append(isbn)
#         url = "http://www.kyobobook.co.kr/product/detailViewKor.laf?mallGb=KOR&ejkGb=KOR&barcode=" + str(isbn) + "&orderClick=JAI"
#         if idx % 100 == 99:
#             driver.quit()
#             s=Service('/opt/ml/chromedriver')
#             driver = webdriver.Chrome(options=options, service=s)
#             driver.implicitly_wait(5)
#         driver.get(url)
       
#         # TODO keywordpick
#         keywordpick_ll = []
#         try:
#             keywordsss = driver.find_element_by_class_name("book_keyword")
#             for i in keywordsss.find_elements_by_xpath('.//*'):
#                 keywordpick_ll.append(i.text)
#         except NoSuchElementException as n:
#             keywordpick_ll=[]
#         keywordpick.append(keywordpick_ll)
#         # TODO author
#         author_ll = []
#         # author = []
#         try:
#             name = driver.find_element_by_class_name("name")
#             author_ll.append(name.text)
#         except NoSuchElementException as n:
#             author_ll = []
#         # onebookdict['author'] = author_ll
#         # if(len(author) == 0):
#         #     author_ll=[]
#         author.append(author_ll)
#         # TODO title
#         title_ll=[]
#         try:
#             titles = driver.find_element_by_xpath('//*[@id="container"]/div[2]/form/div[1]/h1')
#             title_ll.append(titles.text)
#         except NoSuchElementException as n:
#             title_ll=[]
#         # onebookdict['title'] = title_ll
#         # print(title_ll)
#         title.append(title_ll)
#         # TODO image
#         image_ll=[]
#         try:
#             images = driver.find_element_by_xpath('//*[@id="container"]/div[2]/form/div[2]/div[1]/div/a/img').get_attribute("src") # 크게 뜬 이미지 선택하여 "src" 속성을 받아옴
#             image_ll.append(images)
#         except NoSuchElementException as n:
#             image_ll=[]
#         image.append(image_ll)
#         # TODO tag_list(주제어)
#         # tag_ll=[]
#         try:
#             tag = driver.find_elements_by_class_name("tag_list")
#             if(len(tag) != 0):
#                 temp = re.sub('#', '', tag[0].text)
#                 tags = temp.split(' ')
#             else:
#                 tags = []
        
#             # tag_ll.append()
#         except NoSuchElementException as n:
#             tags = []
#         keywords.append(tags)

#         # TODO 책소개, 책 속으로, 목차 한꺼번에 버튼클릭은 해결못함
#         # title_detail_basic2
#         # box_detail_article

#         # box_detail_comment
#         description_ll=[]
#         mokcha_ll=[]
#         try:
#             detail = driver.find_elements_by_class_name("box_detail_article")     
#             for i in detail:
#                 if(len(i.text)!=0):
#                     if(i.text != '이 도서는 목차가 없습니다.' and i.text != '이 상품은 목차가 없습니다.'):
#                         if(i.text[0].isdigit() or i.text[0] == '제'):
#                             # TODO 목차정보
#                             mokcha_ll.append(i.text)
#                         else:
#                             description_ll.append(i.text)
#         except NoSuchElementException as n:
#             mokcha_ll = []
#             description_ll = []
#         mokcha.append(mokcha_ll)
#         description.append(description_ll)

#         # TODO Catchphrase
#         catch_ll=[]
#         try:
#             detail2 = driver.find_elements_by_class_name("title_detail_basic2")
#             if len(detail2) != 0:
#                 for i in detail2:
#                     if(i.text != '북소믈리에 한마디!'):
#                         catch_ll.append(i.text)
#                         # print(i.text)
#                 # onebookdict['Catchphrase'] = catch_ll
#             else:
#                 catch_ll=[]
#                 # onebookdict['Catchphrase'] = [None]
#         except NoSuchElementException as n:
#             catch_ll=[]
#         catchphrase.append(catch_ll)

#     data['author'] = author
#     data['title'] = title
#     data['image'] = image
#     data['keywordpick'] = keywordpick
#     data['keywords'] = keywords
#     # data['text'] = text
#     data['isbn'] = isbn_t
#     data['mokcha'] = mokcha
#     data['description'] = description
#     data['catchphrase'] = catchphrase

#     driver.quit()
#     data.to_csv("{}_kyobo.csv".format(genre_info), index=False)

#     # break



# TODO 장르소설
data = pd.DataFrame()
s=Service('/opt/ml/chromedriver')
driver = webdriver.Chrome(options=options, service=s)
driver.implicitly_wait(5)
keywordpick = []
keywords = []
isbn_t = []
description = []
mokcha = []
catchphrase = []
title = []
author = []
image = []
for idx, isbn in enumerate(tqdm(theme)):
    genre_info = '장르소설'
    isbn_t.append(isbn)
    
    url = "http://www.kyobobook.co.kr/product/detailViewKor.laf?mallGb=KOR&ejkGb=KOR&barcode=" + str(isbn) + "&orderClick=JAI"
    if idx % 100 == 99:
        driver.quit()
        s=Service('/opt/ml/chromedriver')
        driver = webdriver.Chrome(options=options, service=s)
        driver.implicitly_wait(5)
    driver.get(url)
    

    # TODO author
    author_ll = []
    # author = []
    try:
        name = driver.find_element_by_class_name("name")
        author_ll.append(name.text)
    except NoSuchElementException as n:
        author_ll = []
 
    # onebookdict['author'] = author_ll
    # if(len(author) == 0):
    #     author_ll=[]
    author.append(author_ll)

    # TODO title
    title_ll=[]
    try:
        titles = driver.find_element_by_xpath('//*[@id="container"]/div[2]/form/div[1]/h1')
        title_ll.append(titles.text)
    except NoSuchElementException as n:
        title_ll=[]
    # onebookdict['title'] = title_ll
    # print(title_ll)
    title.append(title_ll)

    # TODO image
    image_ll=[]
    try:
        images = driver.find_element_by_xpath('//*[@id="container"]/div[2]/form/div[2]/div[1]/div/a/img').get_attribute("src") # 크게 뜬 이미지 선택하여 "src" 속성을 받아옴
        image_ll.append(images)
    except NoSuchElementException as n:
        image_ll=[]
    image.append(image_ll)

    # TODO keywordpick
    keywordpick_ll = []
    try:
        keywordsss = driver.find_element_by_class_name("book_keyword")
        for i in keywordsss.find_elements_by_xpath('.//*'):
            keywordpick_ll.append(i.text)
    except NoSuchElementException as n:
        keywordpick_ll=[]
    keywordpick.append(keywordpick_ll)
    
    # TODO tag_list(주제어)
    # tag_ll=[]
    try:
        tag = driver.find_elements_by_class_name("tag_list")
        if(len(tag) != 0):
            temp = re.sub('#', '', tag[0].text)
            tags = temp.split(' ')
        else:
            tags = []
    
        # tag_ll.append()
    except NoSuchElementException as n:
        tags = []
    keywords.append(tags)
# TODO 책소개, 책 속으로, 목차 한꺼번에 버튼클릭은 해결못함
        # title_detail_basic2
        # box_detail_article

        # box_detail_comment
    description_ll=[]
    mokcha_ll=[]
    try:
        detail = driver.find_elements_by_class_name("box_detail_article")     
        for i in detail:
            if(len(i.text)!=0):
                if(i.text != '이 도서는 목차가 없습니다.' and i.text != '이 상품은 목차가 없습니다.'):
                    if(i.text[0].isdigit() or i.text[0] == '제'):
                        # TODO 목차정보
                        mokcha_ll.append(i.text)
                    else:
                        description_ll.append(i.text)
    except NoSuchElementException as n:
        mokcha_ll = []
        description_ll = []
    mokcha.append(mokcha_ll)
    description.append(description_ll)

    # TODO Catchphrase
    catch_ll=[]
    try:
        detail2 = driver.find_elements_by_class_name("title_detail_basic2")
        if len(detail2) != 0:
            for i in detail2:
                if(i.text != '북소믈리에 한마디!'):
                    catch_ll.append(i.text)
                    # print(i.text)
            # onebookdict['Catchphrase'] = catch_ll
        else:
            catch_ll=[]
            # onebookdict['Catchphrase'] = [None]
    except NoSuchElementException as n:
        catch_ll=[]
    catchphrase.append(catch_ll)


data['author'] = author
data['title'] = title
data['image'] = image
data['keywordpick'] = keywordpick
data['keywords'] = keywords
data['isbn'] = isbn_t
data['mokcha'] = mokcha
data['description'] = description
data['catchphrase'] = catchphrase

driver.quit()
data.to_csv(genre_info + '_kyobo.csv', index=False)
# Out:
#   0%|          | 0/1404 [00:00<?, ?it/s]/tmp/ipykernel_32733/2256819841.py:177: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   name = driver.find_element_by_class_name("name")
# /tmp/ipykernel_32733/2256819841.py:190: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   titles = driver.find_element_by_xpath('//*[@id="container"]/div[2]/form/div[1]/h1')
# /tmp/ipykernel_32733/2256819841.py:201: DeprecationWarning: find_element_by_xpath is deprecated. Please use find_element(by=By.XPATH, value=xpath) instead
#   images = driver.find_element_by_xpath('//*[@id="container"]/div[2]/form/div[2]/div[1]/div/a/img').get_attribute("src") # 크게 뜬 이미지 선택하여 "src" 속성을 받아옴
# /tmp/ipykernel_32733/2256819841.py:210: DeprecationWarning: find_element_by_class_name is deprecated. Please use find_element(by=By.CLASS_NAME, value=name) instead
#   keywordsss = driver.find_element_by_class_name("book_keyword")
# /tmp/ipykernel_32733/2256819841.py:211: DeprecationWarning: find_elements_by_xpath is deprecated. Please use find_elements(by=By.XPATH, value=xpath) instead
#   for i in keywordsss.find_elements_by_xpath('.//*'):
# /tmp/ipykernel_32733/2256819841.py:220: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   tag = driver.find_elements_by_class_name("tag_list")
# /tmp/ipykernel_32733/2256819841.py:239: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   detail = driver.find_elements_by_class_name("box_detail_article")
# /tmp/ipykernel_32733/2256819841.py:257: DeprecationWarning: find_elements_by_class_name is deprecated. Please use find_elements(by=By.CLASS_NAME, value=name) instead
#   detail2 = driver.find_elements_by_class_name("title_detail_basic2")
# 100%|██████████| 1404/1404 [1:42:38<00:00,  4.39s/it]

# %%
data
# Out:
#           author                                  title  \
# 0      [요코제키 다이]                                [루팡의 딸]
# 1          [강미강]             [옷소매 붉은 끝동 2(완결) 강미강 장편소설]
# 2      [요코제키 다이]                       [루팡의 딸 2 루팡의 귀환]
# 3     [J. K. 롤링]              [해리 포터와 마법사의 돌(미나리마 에디션)]
# 4           [싱숑]  [전지적 독자 시점 PART 1(제4의 벽 북스탠드 에디션 세트)]
# ...          ...                                    ...
# 1399  [아서 코난 도일]                          [셜록 홈즈 전집 세트]
# 1400       [조강은]                      [낙원의 오후 조강은 장편소설]
# 1401      [테드 창]                                    [숨]
# 1402  [J. K. 롤링]         [해리 포터와 불의 잔 4(해리포터 20주년 개정판)]
# 1403     [다니엘 콜]                            [꼭두각시 살인사건]
#
#                                                   image  \
# 0     [http://image.kyobobook.co.kr/images/book/larg...
# 1     [http://image.kyobobook.co.kr/images/book/larg...
# 2     [http://image.kyobobook.co.kr/images/book/larg...
# 3     [http://image.kyobobook.co.kr/images/book/larg...
# 4     [http://image.kyobobook.co.kr/images/book/larg...
# ...                                                 ...
# 1399  [http://image.kyobobook.co.kr/images/book/larg...
# 1400  [http://image.kyobobook.co.kr/images/book/larg...
# 1401  [http://image.kyobobook.co.kr/images/book/larg...
# 1402  [http://image.kyobobook.co.kr/images/book/larg...
# 1403  [http://image.kyobobook.co.kr/images/book/larg...
#
#                                    keywordpick  \
# 0           [일본소설, 미스터리소설, 추리소설, 미스터리, 도둑, 대부]
# 1                 [한국로맨스소설, 조선, 궁녀, 집주, 임금, 왕]
# 2           [일본소설, 미스터리소설, 추리소설, 미스터리, 수사, 도둑]
# 3     [성장소설, 영미소설, 판타지소설, 영화원작소설, 마법 세계, 영국소설]
# 4        [한국소설, 판타지소설, 공포, 웹 소설, 네이버 웹툰, 페이퍼백]
# ...                                        ...
# 1399        [소설, 추리소설, 추리, 사건 수첩, 마지막 인사, 시리즈]
# 1400             [한국로맨스소설, 사랑, 커피, 상무, 기태, 비서]
# 1401           [소설, 인공지능, 우주, 상상력, SF소설, 연금술사]
# 1402     [소설, 성장소설, 영미소설, 판타지소설, 영화원작소설, 영국소설]
# 1403      [소설, 스릴러, 미스터리소설, 영미소설, 추리소설, 스릴러소설]
#
#                                                keywords           isbn  \
# 0                                  [미스터리소설, 추리소설, 일본소설]  9788998274412
# 1                                      [한국로맨스소설, 조선, 왕]  9791104911521
# 2                                  [미스터리소설, 추리소설, 일본소설]  9791190157346
# 3     [영미소설, 영국소설, 판타지소설, 영화원작소설, 성장소설, 마법, 호그와트, 헤르...  9788983928207
# 4            [한국소설, 판타지소설, 웹소설, 현실, 혼돈, 공포, 결말, 진실, 예언]  9788934967576
# ...                                                 ...            ...
# 1399                                                 []  9788976041470
# 1400                                    [한국로맨스소설, 비밀연애]  9788963716442
# 1401   [SF소설, 상상력, 시간여행, 인공지능, 외계지성, 평행우주, 자유의지, 인류의미래]  9791164050277
# 1402  [영미소설, 영국소설, 판타지소설, 영화원작소설, 성장소설, 마법, 호그와트, 헤르...  9788983927712
# 1403                        [영미소설, 추리소설, 미스터리소설, 스릴러소설]  9791190157278
#
#                                                  mokcha  \
# 0     [제1장 형사와 결혼하는 방법\n제2장 형사는 도둑을 좋아해\n제3장 초대받지 못한...
# 1                                                    []
# 2                                                    []
# 3     [제1장 살아남은 아이\n제2장 사라진 유리창\n제3장 발신자 없는 편지들\n제4장...
# 4                                                    []
# ...                                                 ...
# 1399  [1. 진홍색 연구 A Study in Scarlet\n2. 네 개의 서명 The ...
# 1400  [1. 바람의 정체\n2. 까마귀의 집\n3. 동백꽃을 쥐어뜯어\n4. 느닷없이 꽃...
# 1401  [4번의 휴고상, 4번의 네뷸러상, 4번의 로커스상 등 최고의 SF에 수여되는 모든...
# 1402  [29장 꿈\n30장 팬시브\n31장 세 번째 과제\n32장 살과 피와 뼈\n33장...
# 1403                                                 []
#
#                                             description  \
# 0     [도둑 집안의 대부 이와오에게는 하나코라는 손녀딸이 있다. 하나코는 자신의 신분을 ...
# 1     [강미강 장편소설『옷소매 붉은 끝동』제2권 완결. 왕은 궁녀를 사랑했다. 그러나 군...
# 2     [도둑 집안의 딸 하나코와 경찰 집안의 아들 카즈마는 사랑스러운 딸 안을 낳고 평범...
# 3     [영화 〈해리 포터〉와 〈신비한 동물사전〉 시리즈에서 비주얼 그래픽을 담당했던 스튜...
# 4     [“이 이야기를 모두 읽고 난 뒤, 당신은 오래도록 잊고 지낸 기억 하나를 되찾는다...
# ...                                                 ...
# 1399  [최 신간 번역으로 만나는 문예춘추사 《셜록 홈즈 시리즈》는 세련된 표지와 읽기 편...
# 1400  [시간은 느리고, 빨랐다. 사랑은 깊고, 추웠다.\n\n“상무님, 왜 꽃을 싫어하세...
# 1401  [새로운 기술이 인간 사회에 도래했을 때, 그것이 지닌 가능성은 인간과 사회를 어떻...
# 1402  [선과 악의 대립 속에서 평범한 어린 소년이 한 사람의 영웅으로 성장해나가는 보편적...
# 1403  [에밀리 백스터 경감은 봉제인형 살인사건과 그녀의 친구 윌리엄 ‘울프’ 폭스가 실종...
#
#                                             catchphrase
# 0                              [도둑 집안의 대부가 변사체로 발견되었다!]
# 1                                                    []
# 2                                   [루팡의 딸이 결혼하고 돌아왔다!]
# 3     [《해리 포터와 마법사의 돌: 미나리마 에디션》 전 세계 동시 출간!\n〈해리 포터...
# 4     [☆☆☆‘네이버 시리즈’ 누적 다운로드 1억☆☆☆\n☆☆☆‘문피아’ 누적 판매 1위...
# ...                                                 ...
# 1399                                                 []
# 1400                                                 []
# 1401  [테드 창의 환상적이고 우아한 SF의 세계!, 북리스트, 커커스 리뷰, 뉴스데이, ...
# 1402      [우리 시대에 가장 사랑받는 21세기의 고전 《해리포터》를 고전답게 재해석하다!]
# 1403  [‘미끼’라는 단어가 새겨진 피해자,\n‘꼭두각시’라는 단어가 새겨진 가해자!, 존...
#
# [1404 rows x 9 columns]
